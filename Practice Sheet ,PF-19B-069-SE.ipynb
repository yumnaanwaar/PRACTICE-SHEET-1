# %% [markdown]
# # Practice Sheet 1 - Python Programming

# %% [markdown]
# Asst. Prof. Syed Faisal Ali              $\;\;\;\;\;\;$              Programming Fundamentals - FALL 2019 $\;\;\;\;\;\;$ Software Engineering                     $\;\;\;\;\;\;$                   Dated: 7 Nov 2019

# %% [markdown]
# # Yumna Anwaar 19B-069-SE

# %% [markdown]
# Q1: Show how we can import 10 differnt functions from math library of python, such as trignometric or hyperbolic functions and two constants pi and e, and store 6 different angles such as zero, thirty, forty five, sixty, ninty and one hundred and eighty. Show them how you will use in program by giving them some values and print them.

# %%
# start(12.00) p.m , end (12.10)
from math import pi,sin,cos,e,log,tan,acosh,asinh,tanh,sqrt
print("sin pi is",sin(pi))
print("sin zero is",sin(0))
print("cos thirty is",cos(30))
print("log base e is",log(e))
print("tan forty is",tan(45))
print("acosh sixty is",acosh(60))
print("asinh ninety is",asinh(90))
print("tanh 180 is",sin(180))
print("square root of 625 is",sqrt(625))
# Out:
# sin pi is 1.2246467991473532e-16
# sin zero is 0.0
# cos thirty is 0.15425144988758405
# log base e is 1.0
# tan forty is 1.6197751905438615
# acosh sixty is 4.787422291102689
# asinh ninety is 5.192987713658941
# tanh 180 is -0.8011526357338304
# square root of 625 is 25.0

# %% [markdown]
# Q2. Use help() command to show what is math library, int, and class.

# %%
#(12.15):(12.17)
import math
help(math)
help(int)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(...)
#         acos(x)
#
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(...)
#         acosh(x)
#
#         Return the inverse hyperbolic cosine of x.
#
#     asin(...)
#         asin(x)
#
#         Return the arc sine (measured in radians) of x.
#
#     asinh(...)
#         asinh(x)
#
#         Return the inverse hyperbolic sine of x.
#
#     atan(...)
#         atan(x)
#
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(...)
#         atan2(y, x)
#
#         Return the arc tangent (measured in radians) of y/x.
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(...)
#         atanh(x)
#
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(...)
#         ceil(x)
#
# ...

# %% [markdown]
# Q3. Use len() function to show the lenght of your name stored in a variable my_name.

# %%
#(12.17):(12.18)
my_name = "YUMNA"
print("length of my name is",len(my_name))
# Out:
# length of my name is 5

# %% [markdown]
# Q4: We use type() function to show the type of the variable. Your task is to use it on different type of variables in which you save your name, date of birth, cell number, email, favourite dish, favourite color, favourite movie, favourite flower, etc.

# %%
#(12.18):(12.23)
import datetime
name = str("yumna")
dateofbirth=datetime.datetime(2002,3,13)
cell_num = int(3142178177)
email = str("yumna.anwaarahmed@gmail.com")
fav_dish = str("chineese")
fav_color = str("black")
fav_movie = str("angry bird")
fav_flower = str("rose")
print("name is: ",type(name))
print("dateofbirth is: ",type(dateofbirth))
print("number is: ",type(cell_num))
print("email is: ",type(email))
print("dish is: ",type(fav_dish))
print("color is: ",type(fav_color))
print("movie is: ",type(fav_movie))
print("flower is: ",type(fav_flower))
# Out:
# name is:  <class 'str'>
# dateofbirth is:  <class 'datetime.datetime'>
# number is:  <class 'int'>
# email is:  <class 'str'>
# dish is:  <class 'str'>
# color is:  <class 'str'>
# movie is:  <class 'str'>
# flower is:  <class 'str'>

# %%
Q5: A football is kicked 1 meter from the ground at an angle of 30 degree with a velocity of 15 m/sec.
Calculate the following:
a. Max height above the ground.
b. Total time in the air.
c. Total distance traveled.
d. Velocity vector at max height.
e. Velocity when the ball hits the ground.

# %%
#(12.23):(12.31)
#(a) for max height
from math import sin
v = float(input("enter the velocity(in m/s):"))
theta =float(input("enter the angle:"))
g = 9.8#earth gravity
h = v**2 * sin(theta)**2 / 2*g
print("v",str(v)+ "m/s")
print("theta",str(theta) + "degree")
print("h",str(h) + "m")
# Out:
# enter the velocity(in m/s):15
# enter the angle:30
# v 15.0m/s
# theta 30.0degree
# h 1076.267655453855m

# %%
#(b) for total time in the air
from math import sin
v = float(input("enter the velocity(in m/s):"))
theta =float(input("enter the angle:"))
g = 9.8#earth gravity
t = 2 * v * sin(theta)/g
print("v",str(v)+ "m/s")
print("theta",str(theta) + "degree")
print("t",str(t) + "sec")
# Out:
# enter the velocity(in m/s):15
# enter the angle:30
# v 15.0m/s
# theta 30.0degree
# t -3.0245866043659033sec

# %%
#(c) for total distance
from math import sin
v = float(input("enter the velocity(in m/s):"))
theta =float(input("enter the angle:"))
g = 9.8#earth gravity
d = v**2 * sin(theta)*2/g
print("v",str(v)+ "m/s")
print("theta",str(theta) + "degree")
print("d",str(d) + "m")
# Out:
# enter the velocity(in m/s):15
# enter the angle:30
# v 15.0m/s
# theta 30.0degree
# d -45.36879906548855m

# %%
#(d) velocity at max height
from math import cos
theta = float(input("enter the angle"))
v = float(input("enter the velocity"))
vix = v * cos(theta)
print("v",str(v)+ "m/s")
print("theta",str(theta)+ "degree")
print("vix",str(vix)+"m/s")
# Out:
# enter the angle30
# enter the velocity15
# v 15.0m/s
# theta 30.0degree
# vix 2.3137717483137608m/s

# %%
#(e)velocity when ball hit the ground
from math import sin
theta = float(input("enter the angle"))
v = float(input("enter the velocity"))
viy = v * sin(theta)
print("v",str(v)+ "m/s")
print("theta",str(theta)+ "degree")
print("viy",str(vix)+"m/s")
# Out:
# enter the angle30
# enter the velocity15
# v 15.0m/s
# theta 30.0degree
# viy 2.3137717483137608m/s

# %% [markdown]
# Q6: A mass of 5 kg is placed in an inclined plane. If 10 N force applied on it and the friction on the inclined plane is 0.4. Find, Sin, Cos and its movement for angle 30, 45 and 60 degrees ?

# %% [markdown]
# ![mass](mass.png)

# %%
#(12.31):(1.31)
#angle 30
from math import sin,cos
mass = eval(input("enter the mass of the block(in kg): "))
force = eval(input("enter the applied force(in N): "))
angle = eval(input("enter the angle of inclination: "))
g = 9.8#earth gravity
#R must be balance out mgcos(angle)
W = mass * g
print("the weight of the block is: ",str(W) + "N")
vertical_component = W * cos(angle)
print("vertical_component (mgcos(angle)) is: ",vertical_component)
#finding the cofficient of friction
#R = vertical_component
#formula: friction force = cofficient of friction * R
friction_force = eval(input("enter the frictional_force of the surface: "))
angle_in_radian = (angle*pi) / 180
R = vertical_component
cofficient_of_friction = friction_force / R
print("cofficient_of_friction is:",cofficient_of_friction)
#10N force + mgsin(angle) must balance out (miu)mgcos(angle)
horizontal_component = W * sin(angle_in_radian)
print("horizontal_component(mgsin(angle)) is: ",horizontal_component)
horizontal_component_with_miu = cofficient_of_friction * W * cos(angle_in_radian)
print("horizontal_component((miu)mgcos(angle)) is: ",horizontal_component_with_miu)
# Out:
# enter the mass of the block(in kg): 5
# enter the applied force(in N): 10
# enter the angle of inclination: 30
# the weight of the block is:  49.0N
# vertical_component (mgcos(angle)) is:  7.558321044491619
# enter the frictional_force of the surface: 0.4
# cofficient_of_friction is: 0.05292180599969533
# horizontal_component(mgsin(angle)) is:  24.499999999999996
# horizontal_component((miu)mgcos(angle)) is:  2.245749792084506

# %%
#angle 45
from math import sin,cos
mass = eval(input("enter the mass of the block(in kg): "))
force = eval(input("enter the applied force(in N): "))
angle = eval(input("enter the angle of inclination: "))
g = 9.8#earth gravity
#R must be balance out mgcos(angle)
W = mass * g
print("the weight of the block is: ",str(W) + "N")
vertical_component = W * cos(angle)
print("vertical_component (mgcos(angle)) is: ",vertical_component)
#finding the cofficient of friction
#R = vertical_component
#formula: friction force = cofficient of friction * R
friction_force = eval(input("enter the frictional_force of the surface: "))
angle_in_radian = (angle*pi) / 180
R = vertical_component
cofficient_of_friction = friction_force / R
print("cofficient_of_friction is:",cofficient_of_friction)
#10N force + mgsin(angle) must balance out (miu)mgcos(angle)
horizontal_component = W * sin(angle_in_radian)
print("horizontal_component(mgsin(angle)) is: ",horizontal_component)
horizontal_component_with_miu = cofficient_of_friction * W * cos(angle_in_radian)
print("horizontal_component((miu)mgcos(angle)) is: ",horizontal_component_with_miu)
# Out:
# enter the mass of the block(in kg): 5
# enter the applied force(in N): 10
# enter the angle of inclination: 45
# the weight of the block is:  49.0N
# vertical_component (mgcos(angle)) is:  25.740777452068755
# enter the frictional_force of the surface: 0.4
# cofficient_of_friction is: 0.015539546182893264
# horizontal_component(mgsin(angle)) is:  34.64823227814083
# horizontal_component((miu)mgcos(angle)) is:  0.5384178056417825

# %%
#angle 60
from math import sin,cos
mass = eval(input("enter the mass of the block(in kg): "))
force = eval(input("enter the applied force(in N): "))
angle = eval(input("enter the angle of inclination: "))
g = 9.8#earth gravity
#R must be balance out mgcos(angle)
W = mass * g
print("the weight of the block is: ",str(W) + "N")
vertical_component = W * cos(angle)
print("vertical_component (mgcos(angle)) is: ",vertical_component)
#finding the cofficient of friction
#R = vertical_component
#formula: friction force = cofficient of friction * R
friction_force = eval(input("enter the frictional_force of the surface: "))
angle_in_radian = (angle*pi) / 180
R = vertical_component
cofficient_of_friction = friction_force / R
print("cofficient_of_friction is:",cofficient_of_friction)
#10N force + mgsin(angle) must balance out (miu)mgcos(angle)
horizontal_component = W * sin(angle_in_radian)
print("horizontal_component(mgsin(angle)) is: ",horizontal_component)
horizontal_component_with_miu = cofficient_of_friction * W * cos(angle_in_radian)
print("horizontal_component((miu)mgcos(angle)) is: ",horizontal_component_with_miu)
# Out:
# enter the mass of the block(in kg): 5
# enter the applied force(in N): 10
# enter the angle of inclination: 60
# the weight of the block is:  49.0N
# vertical_component (mgcos(angle)) is:  -46.66823604034266
# enter the frictional_force of the surface: 0.4
# cofficient_of_friction is: -0.008571140328814172
# horizontal_component(mgsin(angle)) is:  42.43524478543749
# horizontal_component((miu)mgcos(angle)) is:  -0.20999293805594726

# %% [markdown]
# Q7: Three resiters of 10, 20 and 30 ohms are connected in series and in parallel if 10 V is given to them find current and voltages across them.

# %%
#(1.31):(1.45)
R1 = 10
R2 = 20
R3 = 30
v = 10
#in series
Re = R1 + R2 + R3
Ie = v/Re
V1 = Ie*R1
V2 = Ie*R2
V3 = Ie*R3
print("Re",str(Re)+ "ohms")
print("Ie",str(Ie)+ "ampere")
print("V1",str(V1) + "volt")
print("V2",str(V2) + "volt")
print("V3",str(V3) + "volt")
# Out:
# Re 60ohms
# Ie 0.16666666666666666ampere
# V1 1.6666666666666665volt
# V2 3.333333333333333volt
# V3 5.0volt

# %%
R1 = 10
R2 = 20
R3 = 30
Ve = v = 10
# in parallel
Re = 1/R1 + 1/R2 + 1/R3
I1 = Ve/R1
I2 = Ve/R2
I3 = Ve/R3
print("Re",str(Re)+ "ohms")
print("Ve",str(Ve)+ "volt")
print("I1",str(I1) + "ampere")
print("I2",str(I2) + "ampere")
print("I3",str(I3) + "ampere")
# Out:
# Re 0.18333333333333335ohms
# Ve 10volt
# I1 1.0ampere
# I2 0.5ampere
# I3 0.3333333333333333ampere

# %% [markdown]
# Q8. Find the point of intercept if line 1 coordinates are (1,5), (7, 9) and line 2 coordinates are (2,4) (6,9).

# %%
import numpy as np
from fractions import Fraction
#line 1
x1 = 1
y1 = 5
x2 = 7
y2 = 9
print("m1 = ",Fraction((y2-y1),(x2 -x1)))
eq1 ="-2x-3y=13"
#line 2
x3 = 2
y3 = 4
x4 = 6
y4 = 9
print("m2 = ",Fraction((y4-y3),(x4 -x3)))
eq2 ="4y-5x=6"
print("eq1 = ",eq1)
print("eq2 = ",eq2)
a = np.array([[-2,3],[-5,4]])
b = np.array([13,6])
c = np.linalg.solve(a,b)
print("intercepts are: ",c)
# Out:
# m1 =  2/3
# m2 =  5/4
# eq1 =  -2x-3y=13
# eq2 =  4y-5x=6
# intercepts are:  [4.85714286 7.57142857]

# %% [markdown]
# Q9: Write a small program which have unit price of 10 items such as eggs Rs 120 dozen, milk Rs 95 liter, butter 100 Rs for 125 gms, etc Now ask from the user one by one what he wants and how many he wants. Then do the total amount of purchase.

# %%
### unit prices of items
egg = 120/12
milk_ml = 95/1000
gm_butter = 100/125
bread = 50
gm_tomatoes = 10/1000
gm_potato = 60/1000
gm_onion = 70/1000
gm_flour = 150/1000
gm_rice = 120/1000
gm_sugar = 80/1000
a =int(input("enter the numbers of egg: "))
b = int(input("how many ml of milk you want: "))
c = int(input("how many gm of butter you want: "))
d = int(input("how many breads you want: "))
e = int(input("how many gm of tomatoes you want: "))
f = int(input("how many gm of potato you want: "))
g = int(input("how many gm of onion you want: "))
h = int(input("how many gm of flour you want: "))
i = int(input("how many gm of rice you want: "))
j = int(input("how many gm of sugar you want: "))
A = a * egg
B = b * milk_ml
C = c * gm_butter
D = d * bread
E = e * gm_tomatoes
F = f * gm_potato
G = g * gm_onion
H = h * gm_flour
I = i * gm_rice
J = j * gm_sugar
print("total amount of purchase: Rs. ",str(A+B+C+D+E+F+G+H+I+J) + "/-" )
# Out:
# enter the numbers of egg: 12
# how many ml of milk you want: 95
# how many gm of butter you want: 100
# how many breads you want: 50
# how many gm of tomatoes you want: 10
# how many gm of potato you want: 60
# how many gm of onion you want: 70
# how many gm of flour you want: 150
# how many gm of rice you want: 120
# how many gm of sugar you want: 80
# total amount of purchase: Rs.  2760.925/-

# %% [markdown]
# Q10: A 5m 60cm high vertical pole casts a shadow 3m 20 cm long. Find at the same time
# <br>(i) the length of the shadow cast another pole 10m 50cm high
# <br>(ii) the height of a pole which casts a shadow 5m long.

# %%
#Here height of the pole  and length of the shadow are in direct propoprtion
h1 = 560
s1 = 320
h2 = 1025
s3 = 500
#part(i)
s2 = (h1*s3)/h1
print("the shadow of second pole is: ",s2,"cm or",s2/100,"m")
#part(ii)
h3 = (h1*s3)/s1
print("the height of third pole is: ",h2,"cm or",h2/100,"m")
# Out:
# the shadow of second pole is:  500.0 cm or 5.0 m
# the height of third pole is:  1025 cm or 10.25 m
